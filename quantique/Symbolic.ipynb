# %%
from sympy import symbols, Eq, solve

# Définir les symboles comme des entiers positifs
a, b, c, n, v, x, y, z = symbols('a b c n v x y z', integer=True, positive=True)

eq = Eq((n*x + a)**2, n*y + b)
sol = solve(eq, (y))

print (sol)
# Out:
# [(-b + (a + n*x)**2)/n]

# %%
sol[0].subs({a: 2, b: 3, n: 5})
# Out:
# (5*x + 2)**2/5 - 3/5

# %%
seq=Eq(((5*x+2)**2 - 3), 5*v)
ssol = solve(eq, (x))
ssol
# Out:
# [(-a + sqrt(b + n*y))/n]

# %%
# Définir les équations
eq1 = Eq(v, n*x + a)
eq2 = Eq(v**2, n*y + b)
eq3 = Eq(v**3, z*n + c)

# Trouver des solutions littérales pour x, y, z en fonction de a, b, c et n
#solutions = solve((eq1, eq2, eq3), (x, y, z))
solutions = solve((eq1, eq2), (x, y))

print("Solutions littérales :")
print(solutions)
# Out:
# Solutions littérales :
# {x: (-a + v)/n, y: (-b + v**2)/n}

# %%
# Valeurs numériques
a_val = 2
b_val = 3
c_val = 10
n_val = 5

solutions_num = solutions[x].subs({a: a_val, b: b_val, c: c_val, n: n_val})
# Remplacer les valeurs numériques dans la solution littérale
# solutions_num = {sym.subs({a: a_val, b: b_val, c: c_val, n: n_val}) for sym in solutions}

print("Solutions numériques :")
print(solutions_num)
# Out:
# Solutions numériques :
# v/5 - 2/5
